# %%
#Day 5
fruits = ['banana', 'orange', 'mango', 'lemon','lime','apple']
first_fruit, second_fruit, third_fruit, *rest = fruits 
print(first_fruit)
print(fruits[-1])
# Out:
# banana
# apple

# %%
lst=list() # or lst=[]
print(lst)
lst.clear()
fruits = ['banana', 'orange', 'mango', 'lemon', 'kiwi', 'lime']
print(len(fruits))
# Out:
# []
# 6

# %%
print(fruits[0])
print(fruits[-1])
print(fruits)
# Out:
# banana
# ['banana', 'orange', 'mango', 'lemon', 'kiwi', 'lime']

# %%
mixed_data_types=['Mo', 30, '72in']
it_comps=['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
print(it_comps)
print(len(it_comps))
print(it_comps[0])
print(it_comps[3])
print(it_comps[-1])
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
# 7
# Facebook
# Apple
# Amazon

# %%
it_comps.append('Meta')
print(it_comps)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Meta']

# %%
it_comps.insert(4, 'Uber')
print(it_comps)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'Uber', 'IBM', 'Oracle', 'Amazon', 'Meta']

# %%
it_comps[1]=it_comps[1].upper()
print(it_comps)
# Out:
# ['Facebook', 'GOOGLE', 'Microsoft', 'Apple', 'Uber', 'IBM', 'Oracle', 'Amazon', 'Meta']

# %%
full=it_comps + ['#']
full
# Out:
# ['Facebook',
#  'GOOGLE',
#  'Microsoft',
#  'Apple',
#  'Uber',
#  'IBM',
#  'Oracle',
#  'Amazon',
#  'Meta',
#  '#']

# %%
check='GOOGLE' in full
print(check)
# Out:
# True

# %%
full.sort()
full.sort(reverse=True)
full
# Out:
# ['Uber',
#  'Oracle',
#  'Microsoft',
#  'Meta',
#  'IBM',
#  'GOOGLE',
#  'Facebook',
#  'Apple',
#  'Amazon',
#  '#']

# %%
first3=full[3:]
first3
last3=full[:-3]
last3
# Out:
# ['Uber', 'Oracle', 'Microsoft', 'Meta', 'IBM', 'GOOGLE', 'Facebook']

# %%
full.clear()

# %%
full
# Out:
# []

# %%
del full

# %%
front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
back_end = ['Node','Express', 'MongoDB']
all=front_end + back_end
all
# Out:
# ['HTML', 'CSS', 'JS', 'React', 'Redux', 'Node', 'Express', 'MongoDB']

# %%
full_stack=all
#full_stack.insert(5,('Python', 'SQL'))
full_stack.insert(5,'Python')
full_stack.insert(6,'SQL')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 2
#       1 full_stack=all
# ----> 2 full_stack.insert(5,'Python','SQL')
#
# TypeError: insert expected 2 arguments, got 3

# %%
full_stack
# Out:
# ['HTML',
#  'CSS',
#  'JS',
#  'React',
#  'Redux',
#  ('Python', 'SQL'),
#  'Node',
#  'Express',
#  'MongoDB']

# %%
#level 2
ages = [19, 22, 19, 24, 20, 25, 26, 24, 25, 24]
ages.sort()
print(ages[0])
print(ages[-1])
# Out:
# 19
# 26

# %%
print(len(ages))
print((ages[4]+ages[5])/2)
avg=sum(ages)/len(ages)
print( sum(ages)/len(ages) )
print(ages[-1]-ages[0])
print(abs(ages[0]-avg))
print(abs(ages[-1]-avg))
# Out:
# 10
# 24.0
# 22.8
# 7
# 3.8000000000000007
# 3.1999999999999993
